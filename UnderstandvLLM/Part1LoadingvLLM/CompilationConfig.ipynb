# %%
# CompilationConfig
from vllm.config import CompilationConfig

# %%
CompilationConfig??
# Out:
# Init signature:
# CompilationConfig(
#     level: int = None,
#     mode: vllm.config.compilation.CompilationMode = None,
#     debug_dump_path: pathlib.Path | None = None,
#     cache_dir: str = '',
#     compile_cache_save_format: Literal['binary', 'unpacked'] = <factory>,
#     backend: str = '',
#     custom_ops: list[str] = <factory>,
#     splitting_ops: list[str] | None = None,
#     compile_mm_encoder: bool = False,
#     compile_sizes: list[int | str] | None = None,
#     inductor_compile_config: dict = <factory>,
#     inductor_passes: dict[str, str] = <factory>,
#     cudagraph_mode: vllm.config.compilation.CUDAGraphMode = None,
#     cudagraph_num_of_warmups: int = 0,
#     cudagraph_capture_sizes: list[int] | None = None,
#     cudagraph_copy_inputs: bool = False,
#     cudagraph_specialize_lora: bool = True,
#     use_inductor_graph_partition: bool = None,
#     pass_config: vllm.config.compilation.PassConfig = <factory>,
# ...
